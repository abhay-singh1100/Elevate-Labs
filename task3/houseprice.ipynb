# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Housing.csv')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, drop=None)
mainroad_encoded = encoder.fit_transform(df[['mainroad']])
mainroad_encoded_df = pd.DataFrame(mainroad_encoded, columns=encoder.get_feature_names_out(['mainroad']))
df = df.drop(columns=['mainroad'])
df = pd.concat([df, mainroad_encoded_df], axis=1)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories guestroom basement  \
# 0  13300000  7420         4          2        3        no       no
# 1  12250000  8960         4          4        4        no       no
# 2  12250000  9960         3          2        2        no      yes
# 3  12215000  7500         4          2        2        no      yes
# 4  11410000  7420         4          1        2       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
#
#    mainroad_no  mainroad_yes
# 0          0.0           1.0
# 1          0.0           1.0
# 2          0.0           1.0
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, drop=None)
guestroom_encoded = encoder.fit_transform(df[['guestroom']])
guestroom_encoded_df = pd.DataFrame(guestroom_encoded, columns=encoder.get_feature_names_out(['guestroom']))
df = df.drop(columns=['guestroom'])
df = pd.concat([df, guestroom_encoded_df], axis=1)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, drop=None)
basement_encoded = encoder.fit_transform(df[['basement']])
basement_encoded_df = pd.DataFrame(basement_encoded, columns=encoder.get_feature_names_out(['basement']))
df = df.drop(columns=['basement'])
df = pd.concat([df, basement_encoded_df], axis=1)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, drop=None)
hotwaterheating_encoded = encoder.fit_transform(df[['hotwaterheating']])
hotwaterheating_encoded_df = pd.DataFrame(mainroad_encoded, columns=encoder.get_feature_names_out(['hotwaterheating']))
df = df.drop(columns=['hotwaterheating'])
df = pd.concat([df, hotwaterheating_encoded_df], axis=1)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, drop=None)
airconditioning_encoded = encoder.fit_transform(df[['airconditioning']])
airconditioning_encoded_df = pd.DataFrame(airconditioning_encoded, columns=encoder.get_feature_names_out(['airconditioning']))
df = df.drop(columns=['airconditioning'])
df = pd.concat([df, airconditioning_encoded_df], axis=1)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, drop=None)
prefarea_encoded = encoder.fit_transform(df[['prefarea']])
prefarea_encoded_df = pd.DataFrame(prefarea_encoded, columns=encoder.get_feature_names_out(['prefarea']))
df = df.drop(columns=['prefarea'])
df = pd.concat([df, prefarea_encoded_df], axis=1)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, drop=None)
furnishingstatus_encoded = encoder.fit_transform(df[['furnishingstatus']])
furnishingstatus_encoded_df = pd.DataFrame(furnishingstatus_encoded, columns=encoder.get_feature_names_out(['furnishingstatus']))
df = df.drop(columns=['furnishingstatus'])
df = pd.concat([df, furnishingstatus_encoded_df], axis=1)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  parking  mainroad_no  \
# 0  13300000  7420         4          2        3        2          0.0
# 1  12250000  8960         4          4        4        3          0.0
# 2  12250000  9960         3          2        2        2          0.0
# 3  12215000  7500         4          2        2        3          0.0
# 4  11410000  7420         4          1        2        2          0.0
#
#    mainroad_yes  guestroom_no  guestroom_yes  ...  basement_yes  \
# 0           1.0           1.0            0.0  ...           0.0
# 1           1.0           1.0            0.0  ...           0.0
# 2           1.0           1.0            0.0  ...           1.0
# 3           1.0           1.0            0.0  ...           1.0
# 4           1.0           0.0            1.0  ...           1.0
#
#    hotwaterheating_no  hotwaterheating_yes  airconditioning_no  \
# 0                 0.0                  1.0                 0.0
# ...

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking  mainroad_no  mainroad_yes  guestroom_no  guestroom_yes  \
# count  545.000000   545.000000    545.000000    545.000000     545.000000
# mean     0.693578     0.141284      0.858716      0.822018       0.177982
# std      0.861586     0.348635      0.348635      0.382849       0.382849
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   price                            545 non-null    int64
#  1   area                             545 non-null    int64
#  2   bedrooms                         545 non-null    int64
#  3   bathrooms                        545 non-null    int64
#  4   stories                          545 non-null    int64
#  5   parking                          545 non-null    int64
#  6   mainroad_no                      545 non-null    float64
#  7   mainroad_yes                     545 non-null    float64
#  8   guestroom_no                     545 non-null    float64
#  9   guestroom_yes                    545 non-null    float64
#  10  basement_no                      545 non-null    float64
#  11  basement_yes                     545 non-null    float64
# ...

# %%
df['mainroad_yes'] = df['mainroad_yes'].astype(int)

# %%
df['guestroom_no'] = df['guestroom_no'].astype(int)

# %%
df['basement_no'] = df['basement_no'].astype(int)

# %%
df['hotwaterheating_yes'] = df['hotwaterheating_yes'].astype(int)

# %%
df['airconditioning_yes']= df['airconditioning_yes'].astype(int)

# %%
df['prefarea_no'] = df['prefarea_no'].astype(int)

# %%
df['furnishingstatus_furnished'] = df['furnishingstatus_furnished'].astype(int)

# %%
df['furnishingstatus_semi-furnished'] = df['furnishingstatus_semi-furnished'].astype(int)

# %%
df['furnishingstatus_unfurnished'] = df['furnishingstatus_unfurnished'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   price                            545 non-null    int64
#  1   area                             545 non-null    int64
#  2   bedrooms                         545 non-null    int64
#  3   bathrooms                        545 non-null    int64
#  4   stories                          545 non-null    int64
#  5   parking                          545 non-null    int64
#  6   mainroad_no                      545 non-null    float64
#  7   mainroad_yes                     545 non-null    int64
#  8   guestroom_no                     545 non-null    int64
#  9   guestroom_yes                    545 non-null    float64
#  10  basement_no                      545 non-null    int64
#  11  basement_yes                     545 non-null    float64
# ...

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['price']), df['price'], test_size=0.2, random_state=42)

# %%
X_train.head()
# Out:
#      area  bedrooms  bathrooms  stories  parking  mainroad_no  mainroad_yes  \
# 46   6000         3          2        4        1          0.0             1
# 93   7200         3          2        1        3          0.0             1
# 335  3816         2          1        1        2          0.0             1
# 412  2610         3          1        2        0          0.0             1
# 471  3750         3          1        2        0          0.0             1
#
#      guestroom_no  guestroom_yes  basement_no  basement_yes  \
# 46              1            0.0            1           0.0
# 93              1            0.0            0           1.0
# 335             1            0.0            0           1.0
# 412             1            0.0            0           1.0
# 471             1            0.0            1           0.0
#
#      hotwaterheating_no  hotwaterheating_yes  airconditioning_no  \
# 46                  0.0                    1                 0.0
# ...

# %%
pd.DataFrame(y_train.head())
# Out:
#        price
# 46   7525000
# 93   6300000
# 335  3920000
# 412  3430000
# 471  3010000

# %%
from sklearn.linear_model import LinearRegression

regerssion = LinearRegression()

# %%
regerssion.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regerssion
# Out:
# LinearRegression()

# %%
y_pred = regerssion.predict(X_test)

# %%
y_pred
# Out:
# array([5248073.6301381 , 7220404.99546845, 3141248.66246576,
#        4599017.19821428, 3328649.85220602, 3553760.97405168,
#        5619356.95345776, 6415069.22530295, 2760818.06915402,
#        2674104.75592534, 9665918.66845419, 2817197.08533954,
#        3143861.99949994, 3461152.36575193, 3724490.40409235,
#        5324150.38794066, 3077980.48229091, 4775776.77913446,
#        4408323.89365305, 3604716.06526685, 5755279.14987303,
#        5850663.75168492, 2749805.14156489, 4760906.42197374,
#        5334271.49016707, 7637493.23939689, 3244553.57961262,
#        5254443.17644135, 8159292.85764876, 3442983.5890481 ,
#        6483477.50056742, 3360893.69892951, 6714931.75914448,
#        4247035.12596386, 3590734.85557993, 5850465.41149588,
#        4886937.03676483, 4349332.49929322, 3164888.96939775,
#        4654923.41324542, 4629257.05494236, 3479182.09895334,
#        7201487.95861943, 4043800.34583699, 3782063.28572644,
# ...

# %%
from sklearn.metrics import mean_squared_error,root_mean_squared_error,r2_score,mean_absolute_error

print("RMSE:",root_mean_squared_error(y_test, y_pred))
print("R2 score:",r2_score(y_test, y_pred))
print("MAE:",mean_absolute_error(y_test, y_pred))
print("MSE:",mean_squared_error(y_test, y_pred))
# Out:
# RMSE: 1347778.2882476624
# R2 score: 0.6406210170726119
# MAE: 994646.7866486596
# MSE: 1816506314271.7988

# %%
X_test.shape
# Out:
# (109, 20)

# %%
y_test.shape
# Out:
# (109,)

# %%
# If X_test has more than one column, select one for plotting
X_test_single = X_test.iloc[:, 0]  # take the first feature column

plt.figure(figsize=(10, 6))
plt.scatter(X_test_single, y_test, color='blue', label='Actual')

# Sort values for a clean line plot
sorted_idx = X_test_single.argsort()
plt.plot(X_test_single.iloc[sorted_idx], y_pred[sorted_idx], color='red', linewidth=2, label='Regression Line')

plt.xlabel(X_test.columns[0])
plt.ylabel('Target')
plt.title('Linear Regression Line')
plt.legend()
plt.grid(True)
plt.show()
